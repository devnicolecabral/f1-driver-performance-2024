# %% [markdown]
# # 🏎️ Análise de pontuação das equipes - Temporada 2024
#
# 📍 *Notebook 03: Análise de Pontuação das Equipes*
#
# Neste notebook, vamos analisar o desempenho das equipes (constructors) na temporada de 2024. Vamos usar os dados de resultados das corridas para somar os pontos conquistados por cada equipe, criando uma visão geral da classificação atual.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Estilo dos gráficos

# %%
sns.set(style='darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 2. Lendo os dados filtrados e de apoio

# %%
constructor_results_2024 = pd.read_csv('../data_filtrada/constructor_results_2024.csv')
constructors = pd.read_csv('../data/constructors.csv')

# %% [markdown]
# ## 3. Preparando os dados

# %%
# 🔗 Juntando resultados com os dados das equipes
resultados_constructors = constructor_results_2024.merge(constructors, on='constructorId', how='left')

# 🧮 Somando os pontos por equipe
pontuacao_constructors = resultados_constructors.groupby('name')['points'].sum().sort_values(ascending=False).reset_index()

# %% [markdown]
# ## 4. Visualização dos dados

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=pontuacao_constructors, x='points', y='name', palette='Blues_r')
plt.title('Pontuação das Equipes - Temporada 2024', fontsize=16)
plt.xlabel('Pontos')
plt.ylabel('Equipe')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24040\2279081325.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=pontuacao_constructors, x='points', y='name', palette='Blues_r')

# %% [markdown]
# ## 5. Conclusão
#
# Neste notebook, realizamos a análise da pontuação das equipes na temporada de 2024. A partir dos dados de `constructor_results_2024.csv` e `constructors.csv`, conseguimos calcular os pontos totais por equipe e visualizar os resultados com um gráfico de barras.
#
# - 🧠 Essa análise nos ajuda a ver o desempenho das principais equipes.
#
# 👉 **Próximo passo:** `4_analise_de_voltas_rapidas_2024.ipynb`
